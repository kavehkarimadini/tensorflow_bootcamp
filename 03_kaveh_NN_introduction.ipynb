# %% [markdown]
# <center><h1>In the name of Allah</h1></center>
# <center><h2>Introducing neural networks</h2></center>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * The input are the features of the data you have
#
# * The output are the labels of the data you have
# * The hidden layers in a neural network are used to extract and transform the input data into a more useful representation for the output layer.
# * Now the counts of each hidden layers (which are parameters) is completely experimental

# %% [markdown]
# ![01.PNG](attachment:01.PNG)

# %% [markdown]
# * each neuron is atached to another neuron with a weight
# * the weight is first selected randomly
# * the input is then multiplied with the weight and sumed with the other multiplications of weights and inputs
# * then the result is sent to the body, based on the Activation Function(like: relu), it the sends the apropriate output

# %% [markdown]
# # Now what if the inputs are 0 and we want a 1 for output?
# * no matter how we change the weights the output will not become 1.
# * also without the bias the equation will become like aX + bY which will only go across the origine point,
# --> for that purpose we add a bias which then the equation becomes (aX + bY)+B
# ![image.png](attachment:image.png)

# %% [markdown]
# # there are 2 types of classifying, (In my opinion),
# 1) with a non-linear line
# 2) with linear lines
# ![linear_none_linear_classification.jpg](attachment:linear_none_linear_classification.jpg)

# %% [markdown]
# # lets get mathematical:
# * You know from your highschool maths that for finding a optimal point in a equation we need to get the derivative of the function and equall it to 0.
# ![derivative.png](attachment:derivative.png)
# * So we need a derivatable Activation Function

# %% [markdown]
# # whats the point of having hidden layers?
# * One use of having hidden layers is for solving more complex problems that need non-linearity, But...
# * For the hidden layers to work properly (extracting more complex features while going forward), they need activation functions(I would personaly say non-linear functions).
# ![non-linear%20functions.png](attachment:non-linear%20functions.png)

# %% [markdown]
# ![hidden_layers.png](attachment:hidden_layers.png)

# %% [markdown]
# # Cost functions
# * For updating the weights of the NN we need a cost value to work on.
# * One commonly used cost function is the MSE which has the power2 that makes the errors bolder:
# ![MSE.jpg](attachment:MSE.jpg)

# %% [markdown]
# * But one of the cons of this methode is that it slows down the training process
# # A better option is using cross entropy:
# ![image.png](attachment:image.png)
# * the above is a mask formula, in a more simpler way we say:
# * if (y[i] == 1): ... ==> so we only look at the number 6!
# * if you take a closer look to the log diagram, at 1 is 0, but when we go from 1 to 0, the error increases exponentialy!

# %% [markdown]
# # Gradient Descent
# ![image-3.png](attachment:image-3.png)
# * For simplicity lets imagine that we have only on dimension(1 weight):
# * We want as  the weights get updated the slope of the point nears to 0, for that purpose we update the weights like this:
# * W = W - P'(derivative or slope)
# * Now why don't we call it derivative descent, reasone is, we have many variables:
# * W0 = W0 - dc/dW0
# * W1 = W1 - dc/dW1
# ...

# %% [markdown]
# # Backpropagation
# * backpropagation is nothing but the chainrule:
# * we know dY1/dX , dY2/dY1 and dY3/dY2, Then we also can use the chain rule to find dY3/dY1.
# * This concept is used for updating the layers befor the current layer we are updating.
# it goes something like this:
# ![backpropagation.png](attachment:backpropagation.png)

# %% [markdown]
# # Vanishing Gradient
# * In the backpropagation if there are alot of layers, the derivatives are multiplied at each other which will give a very small number.
# * the small number may become so small that the weights won't be updated at all!( this is the problem of the old fasioned sigmoid function)
# ### Now here is another life saving benefits of Relu==> destroying(aproximatly) vanishing gradient!
